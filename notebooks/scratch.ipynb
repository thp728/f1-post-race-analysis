# %% [markdown]
# # F1 Post-Race Analysis — Scratch Notebook
#
# Ad-hoc exploration only. If a pattern proves useful, promote it to `src/`.

# %%
import sys
from pathlib import Path

# Add project root to path
sys.path.insert(0, str(Path.cwd().parent))

from src import loader, metrics, strategy, circuit, prediction

loader.init_cache()

# %%
# Example: load a session directly from FastF1
# session = loader.get_session(2024, 'Bahrain', 'R')
# session.laps.head()

# %%
# Example: load data from the SQLite database
# laps = loader.load_laps_from_db(2024, 1, 'R')
# laps.head()

# %%
# Ad-hoc analysis goes here
